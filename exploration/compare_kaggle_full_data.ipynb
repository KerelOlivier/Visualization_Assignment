# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys

# %%
df_kaggle = pd.read_csv('../data/airbnb_open_data_clean.csv')
df_online = pd.read_csv('../data/too_small_listings.csv')
test = pd.read_csv('../data/airbnb_open_data_full.csv')
# Out:
# C:\Users\ionad\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (68) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
len(df_kaggle)
# Out:
# 102073

# %%
len(df_online)
# Out:
# 39881

# %%
len(test)
# Out:
# 39881

# %%
df_kaggle
# Out:
#               id                                              name  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 2        1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3        1002755                                               NaN
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# ...          ...                                               ...
# 102068  57365208               Cozy bright room near Prospect Park
# 102069  57365760         Private Bedroom with Amazing Rooftop View
# 102070  57366313     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102071  57366865        Room & private bathroom in historic Harlem
# 102072  57367417                                   Rosalee Stewart
#
#             host_id host_identity_verified host_name       neighbourhood  \
# 0       80014485718            unconfirmed  Madaline          Kensington
# ...

# %%
df_online
# Out:
#                        id                                      listing_url  \
# 0                    2539                https://www.airbnb.com/rooms/2539
# 1                    2595                https://www.airbnb.com/rooms/2595
# 2                    5121                https://www.airbnb.com/rooms/5121
# 3                   45910               https://www.airbnb.com/rooms/45910
# 4                    5136                https://www.airbnb.com/rooms/5136
# ...                   ...                                              ...
# 39876            43728504            https://www.airbnb.com/rooms/43728504
# 39877            44578886            https://www.airbnb.com/rooms/44578886
# 39878            46355090            https://www.airbnb.com/rooms/46355090
# 39879  698195550745703156  https://www.airbnb.com/rooms/698195550745703156
# 39880            48971505            https://www.airbnb.com/rooms/48971505
#
#             scrape_id last_scraped           source  \
# ...

# %%
df_online[(df_online.latitude==40.81315) & (df_online.longitude==-73.94747)]
# Out:
# Empty DataFrame
# ...

# %%
count = df_kaggle.groupby(['lat', 'long'], as_index=False).size().reset_index(drop=True)

# %%
df_kaggle[(df_kaggle.lat==40.50708) & (df_kaggle.long==-74.24285)]
# Out:
#              id                            name      host_id  \
# 15295   9439928  Villa DiGioia visit NYC via SI  73755720244
# 85116  48002618  Villa DiGioia visit NYC via SI  72639175396
#
#       host_identity_verified  host_name neighbourhood       lat      long  \
# 15295               verified  Michael J   Tottenville  40.50708 -74.24285
# 85116               verified  Michael J   Tottenville  40.50708 -74.24285
#
#       instant_bookable cancellation_policy  ... service_fee  minimum_nights  \
# 15295             True              strict  ...        56.0             2.0
# 85116             True              strict  ...        56.0             2.0
#
#        number_of_reviews  last_review  reviews_per_month  review_rate_number  \
# 15295                0.0          NaN                NaN                 2.0
# 85116                0.0          NaN                NaN                 2.0
#
#       calculated_host_listings_count  availability_365  \
# ...

# %%
df_kaggle[(df_kaggle.lat==40.50868) & (df_kaggle.long==-74.23986)]
# Out:
#              id                                             name      host_id  \
# 1441    1788364  Beautiful 4BR/4BA Home, Staten Island, NY City.  63542823809
# 69617  39441968  Beautiful 4BR/4BA Home, Staten Island, NY City.  78761503890
#
#       host_identity_verified host_name neighbourhood       lat      long  \
# 1441                verified    Marina   Tottenville  40.50868 -74.23986
# 69617            unconfirmed    Marina   Tottenville  40.50868 -74.23986
#
#       instant_bookable cancellation_policy  ... service_fee  minimum_nights  \
# 1441              True              strict  ...       150.0             3.0
# 69617             True            flexible  ...       150.0             3.0
#
#        number_of_reviews  last_review  reviews_per_month  review_rate_number  \
# 1441                59.0   2019-07-08               0.82                 2.0
# 69617               59.0   2019-07-08               0.82                 2.0
#
# ...

# %%
df_kaggle[(df_kaggle.lat==40.89873) & (df_kaggle.long==-73.86449)]
# Out:
#              id                                               name  \
# 30596  17890670  LATE CHECK IN DISCOUNT! NO CLEANING FEE! 2/5 t...
# 73553  41616373  LATE CHECK IN DISCOUNT! NO CLEANING FEE! 2/5 t...
# 93528  52648566  LATE CHECK IN DISCOUNT! NO CLEANING FEE! 2/5 t...
#
#            host_id host_identity_verified host_name neighbourhood       lat  \
# 30596  73672455110            unconfirmed     Shera      Woodlawn  40.89873
# 73553  47195636695            unconfirmed     Shera      Woodlawn  40.89873
# 93528  88269149206               verified     Shera      Woodlawn  40.89873
#
#            long instant_bookable cancellation_policy  ... service_fee  \
# 30596 -73.86449            False              strict  ...        75.0
# 73553 -73.86449            False              strict  ...        75.0
# 93528 -73.86449            False            moderate  ...        75.0
#
#        minimum_nights  number_of_reviews  last_review  reviews_per_month  \
# ...

# %%
count[count['size']==3]
# Out:
#             lat      long  size
# 76     40.56933 -74.09493     3
# 79     40.57044 -74.11747     3
# 139    40.57608 -73.96140     3
# 160    40.57688 -73.95308     3
# 163    40.57701 -73.96616     3
# ...         ...       ...   ...
# 67090  40.89691 -73.85121     3
# 67103  40.89811 -73.85543     3
# 67112  40.89873 -73.86449     3
# 67125  40.90175 -73.89761     3
# 67132  40.90356 -73.84172     3
#
# [2655 rows x 3 columns]

# %%
count2 = df_online.groupby(['latitude', 'longitude'], as_index=False).size().reset_index(drop=True)

# %%
count.groupby('size').size().sort_values(ascending=False)
# Out:
# size
# 1     40101
# 2     21885
# 3      2655
# 4      2486
# 6        10
# 5         8
# 7         5
# 11        3
# 8         3
# 15        2
# 9         2
# 31        1
# 14        1
# dtype: int64

# %%
count2.groupby('size').size().sort_values(ascending=False)
# Out:
# size
# 1     38467
# 2       157
# 3        50
# 4        31
# 5        20
# 6         9
# 10        7
# 7         6
# 8         6
# 11        5
# 9         4
# 24        3
# 17        2
# 12        2
# 53        1
# 49        1
# 14        1
# 16        1
# 18        1
# 19        1
# 21        1
# 22        1
# 30        1
# 36        1
# 13        1
# dtype: int64

# %%
count2[count2['size']==2]
# Out:
#         latitude  longitude  size
# 101    40.576569 -73.985207     2
# 188    40.579930 -73.837486     2
# 237    40.581832 -73.830652     2
# 553    40.593220 -74.068570     2
# 809    40.605510 -74.016620     2
# ...          ...        ...   ...
# 37229  40.840750 -73.936510     2
# 37427  40.845810 -73.942120     2
# 37808  40.855850 -73.929470     2
# 38390  40.881000 -73.835110     2
# 38403  40.882013 -73.849521     2
#
# [157 rows x 3 columns]

# %%
df_online[(df_online.latitude==40.593220)&(df_online.longitude==-74.068570)]
# Out:
#              id                            listing_url       scrape_id  \
# 10114  17073870  https://www.airbnb.com/rooms/17073870  20220907064715
# 10295  17716523  https://www.airbnb.com/rooms/17716523  20220907064715
#
#       last_scraped       source  \
# 10114   2022-09-07  city scrape
# 10295   2022-09-07  city scrape
#
#                                                     name  \
# 10114         South Beach Apartment Express to Manhattan
# 10295  30 Minutes from Manhattan Apartment in South B...
#
#                                              description  \
# 10114  Beautiful Renovated apartment 2 blocks from So...
# 10295  Renovated Apartment 2 blocks from the Beach wi...
#
#                                    neighborhood_overview  \
# 10114  Its a pretty quiet neighborhood and safe at ni...
# 10295  South Beach is a quiet area in New York, yet c...
#
#                                              picture_url   host_id  ...  \
# ...

# %%
df_online[(df_online.latitude==40.881000)&(df_online.longitude==-73.835110	)]
# Out:
#            id                           listing_url       scrape_id  \
# 127     63610    https://www.airbnb.com/rooms/63610  20220907064715
# 3464  4963511  https://www.airbnb.com/rooms/4963511  20220907064715
#
#      last_scraped       source  \
# 127    2022-09-07  city scrape
# 3464   2022-09-07  city scrape
#
#                                                    name  \
# 127   DOMINIQUE'S mini guest suite Efficiency pad* M...
# 3464  Vie's 3bedrm crashpad* sleeps7 *Metro*street prkg
#
#                                             description  \
# 127   **Clean accommodations**<br />safe home-sleeps...
# 3464  The Bronx is famous for its Co-Op City, the la...
#
#                                   neighborhood_overview  \
# 127   Come visit the Big Apple* Times Square* see a ...
# 3464  A  safe,  quiet, diverse neighborhood with res...
#
#                                             picture_url  host_id  ...  \
# ...
